# %% [markdown]
# <a href="https://colab.research.google.com/github/dhruvterminator/Netflix-Stock-Price-Prediction/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ***Netflix Stock Price Prediction***

# %% [markdown]
# 1. Import Libraries

# %%
#import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# 2. Load Dataset

# %%
df = pd.read_csv('/content/NFLXdaily.csv')
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2019-01-02  259.279999  269.750000  256.579987  267.660004  267.660004
# 1  2019-01-03  270.200012  275.790009  264.429993  271.200012  271.200012
# 2  2019-01-04  281.880005  297.799988  278.540009  297.570007  297.570007
# 3  2019-01-07  302.100006  316.799988  301.649994  315.339996  315.339996
# 4  2019-01-08  319.980011  320.589996  308.010010  320.269989  320.269989
#
#      Volume
# 0  11679500
# 1  14969600
# 2  19330100
# 3  18620100
# 4  15359200

# %% [markdown]
# 3. Exploratory Data Analysis (EDA)

# %%
#Exploratory Data Analysis(EDA)
# Check basic information
df.info()
# Check for missing values
df.isnull().sum()
# Check for duplicate rows
df.duplicated().sum()
# Drop duplicate rows if any
df = df.drop_duplicates()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 335 entries, 0 to 334
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       335 non-null    object
#  1   Open       335 non-null    float64
#  2   High       335 non-null    float64
#  3   Low        335 non-null    float64
#  4   Close      335 non-null    float64
#  5   Adj Close  335 non-null    float64
#  6   Volume     335 non-null    int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 18.4+ KB

# %% [markdown]
# Statistical Summary

# %%
df.describe()
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  335.000000  335.000000  335.000000  335.000000  335.000000
# mean   337.713045  343.117732  332.586597  338.210626  338.210626
# std     37.534396   38.179600   36.922828   37.462731   37.462731
# min    255.710007  265.000000  252.279999  254.589996  254.589996
# 25%    306.095001  311.619995  302.160004  307.324997  307.324997
# 50%    345.880005  351.769989  341.019989  345.609985  345.609985
# 75%    364.925003  369.959992  359.564988  364.104996  364.104996
# max    444.769989  449.519989  431.609985  439.170013  439.170013
#
#              Volume
# count  3.350000e+02
# mean   8.033522e+06
# std    4.551888e+06
# min    2.019300e+06
# 25%    5.161650e+06
# 50%    6.636900e+06
# 75%    9.200550e+06
# max    3.825890e+07

# %% [markdown]
# 4. Visualizing Data Distribution

# %%
# Visualizing Data Distribution
# Use distplot for key features
for column in ['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']:
    plt.figure(figsize=(8,4))
    sns.histplot(df[column], kde=True, bins=30)
    plt.title(f'Distribution of {column}')
    plt.show()

# %% [markdown]
# 5. Handling Outliers

# %%
#Handling Outliers
#Boxplot to Detect Outliers
for column in ['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']:
    plt.figure(figsize=(8,4))
    sns.boxplot(x=df[column])
    plt.title(f'Boxplot of {column}')
    plt.show()

# %% [markdown]
# 6. Feature Correlation Analysis

# %% [markdown]
# Pairplot

# %%
#Feature Correlation Analysis
#Pairplot
sns.pairplot(df[['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']])
plt.show()

# %% [markdown]
# Heatmap

# %%
#heatmap
plt.figure(figsize=(10,8))
corr = df[['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']].corr()
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# 7. Data Preprocessing

# %% [markdown]
# Date Feature Engineering

# %%
# Load the dataset
df = pd.read_csv('/content/NFLXdaily.csv')  # your file path

# Fix column names (remove spaces or hidden characters)
df.columns = df.columns.str.strip()

# Now safely access 'Date'
df['Date'] = pd.to_datetime(df['Date'])

# Feature Extraction
df['Year'] = df['Date'].dt.year
df['Month'] = df['Date'].dt.month
df['Day'] = df['Date'].dt.day

# Drop 'Date' column
df = df.drop('Date', axis=1)

df.head()
# Out:
#          Open        High         Low       Close   Adj Close    Volume  Year  \
# 0  259.279999  269.750000  256.579987  267.660004  267.660004  11679500  2019
# 1  270.200012  275.790009  264.429993  271.200012  271.200012  14969600  2019
# 2  281.880005  297.799988  278.540009  297.570007  297.570007  19330100  2019
# 3  302.100006  316.799988  301.649994  315.339996  315.339996  18620100  2019
# 4  319.980011  320.589996  308.010010  320.269989  320.269989  15359200  2019
#
#    Month  Day
# 0      1    2
# 1      1    3
# 2      1    4
# 3      1    7
# 4      1    8

# %% [markdown]
# Define Features and Target

# %%
X = df.drop('Close', axis=1)
y = df['Close']

# %% [markdown]
# Normalize Features

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# 8. Train-Test Split

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

print(f"X_train shape: {X_train.shape}")
print(f"X_test shape: {X_test.shape}")
# Out:
# X_train shape: (268, 8)
# X_test shape: (67, 8)

# %% [markdown]
# 9. Model Building

# %% [markdown]
# Model 1: Linear Regression

# %%
#9. Model Building
#Model 1: Linear Regression
lr_model = LinearRegression()
lr_model.fit(X_train, y_train)

y_pred_lr = lr_model.predict(X_test)

print("Linear Regression Performance:")
print("MSE:", mean_squared_error(y_test, y_pred_lr))
print("R2 Score:", r2_score(y_test, y_pred_lr))
# Out:
# Linear Regression Performance:
# MSE: 5.787177793048234e-28
# R2 Score: 1.0

# %% [markdown]
# Model 2: Random Forest Regressor

# %%
#Model 2: Random Forest Regressor
rf_model = RandomForestRegressor(n_estimators=100, random_state=42)
rf_model.fit(X_train, y_train)

y_pred_rf = rf_model.predict(X_test)

print("Random Forest Regressor Performance:")
print("MSE:", mean_squared_error(y_test, y_pred_rf))
print("R2 Score:", r2_score(y_test, y_pred_rf))
# Out:
# Random Forest Regressor Performance:
# MSE: 2.639393257731466
# R2 Score: 0.9982889310920273

# %% [markdown]
# 10. Model Comparison

# %%
#10. Model Comparison
models = pd.DataFrame({
    'Model': ['Linear Regression', 'Random Forest Regressor'],
    'MSE': [mean_squared_error(y_test, y_pred_lr), mean_squared_error(y_test, y_pred_rf)],
    'R2 Score': [r2_score(y_test, y_pred_lr), r2_score(y_test, y_pred_rf)]
})

print(models)
# Out:
#                      Model           MSE  R2 Score
# 0        Linear Regression  5.787178e-28  1.000000
# 1  Random Forest Regressor  2.639393e+00  0.998289

# %% [markdown]
# ***🎯 Conclusion:***
# Random Forest is expected to outperform Linear Regression due to its power in handling non-linear patterns.
#
# You could improve further by:
#
# Adding technical indicators (moving averages, RSI, etc.).
#
# Hyperparameter tuning (GridSearchCV for Random Forest).
#
# Trying deep learning models (LSTM, GRU) for time series!
